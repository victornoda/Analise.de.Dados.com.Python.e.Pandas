# %%
animais = [1,2,3] #criando uma lista chamada "animais"

# %%
animais
# Out:
# [1, 2, 3]

# %%
animais = ['cachorro', 'gato', 123456, 6.5]
animais
# Out:
# ['cachorro', 'gato', 123456, 6.5]

# %%
animais[0]
# Out:
# 'cachorro'

# %%
animais[3]
# Out:
# 6.5

# %%
animais[0] = 'papagaio'

# %%
animais
# Out:
# ['papagaio', 'gato', 123456, 6.5]

# %%
animais.remove('gato')

# %%
animais
# Out:
# ['papagaio', 123456, 6.5]

# %%
len(animais)
# Out:
# 3

# %%
'gato' in animais
# Out:
# False

# %%
'123456' in animais
# Out:
# False

# %%
123456 in animais
# Out:
# True

# %%
lista = [500, 30, 300, 80, 10]

# %%
max(lista)
# Out:
# 500

# %%
min(lista)
# Out:
# 10

# %%
animais.append('leao') #só aceita um argumento

# %%
animais
# Out:
# ['papagaio', 123456, 6.5, 'leao']

# %%
animais.extend(['cobra', 6])

# %%
animais
# Out:
# ['papagaio', 123456, 6.5, 'leao', 'leao', 'cobra', 6]

# %%
animais.count('cachorro')
# Out:
# 0

# %%
lista.sort()

# %%
lista
# Out:
# [10, 30, 80, 300, 500]

# %% [markdown]
# tupla

# %%
tp = ('Banana', 'Maca', 10, 50)

# %%
tp[0]
# Out:
# 'Banana'

# %%
# Tuplas são imutáveis, ou seja, não pdomeos alterar seus elementos
tp[0] = 'Laranja'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-47c0d06177d5> in <module>()
#       1 # Tuplas são imutáveis, ou seja, não pdomeos alterar seus elementos
# ----> 2 tp[0] = 'Laranja'
#
# TypeError: 'tuple' object does not support item assignment

# %%
tp.count(maca)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6bc1efad7e8f> in <module>()
# ----> 1 tp.count(maca)
#
# NameError: name 'maca' is not defined

# %%
tp.count(Maca)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-3916c57139bf> in <module>()
# ----> 1 tp.count(Maca)
#
# NameError: name 'Maca' is not defined

# %%
tp.count('Maca')
# Out:
# 1

# %%
tp.count('maca')
# Out:
# 0

# %%
tp[0:2]
# Out:
# ('Banana', 'Maca')

# %%
tp[0:1]
# Out:
# ('Banana',)

# %% [markdown]
# dicionarios

# %%
dc = {'Maca' : 20, 'Banana' : 10, 'Laranja' : 15, 'Uva' : 5}

# %%
dc
# Out:
# {'Banana': 10, 'Laranja': 15, 'Maca': 20, 'Uva': 5}

# %%
dc['Maca']
# Out:
# 20

# %%
# Atualizando o valor da maçã
dc['Maca'] = 25
dc
# Out:
# {'Banana': 10, 'Laranja': 15, 'Maca': 25, 'Uva': 5}

# %%
# Retornando todas as chaves do dicionário
dc.keys()
# Out:
# dict_keys(['Maca', 'Banana', 'Laranja', 'Uva'])

# %%
# Retornando todas os valores do dicionário
dc.values()
# Out:
# dict_values([25, 10, 15, 5])

# %%
# Verificando se já existe uma chave no dicionário e caso não exista inserir
dc.setdefault("Limão", 22)
# Out:
# 22

# %%
dc
# Out:
# {'Banana': 10, 'Laranja': 15, 'Limão': 22, 'Maca': 25, 'Uva': 5}
