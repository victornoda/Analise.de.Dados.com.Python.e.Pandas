# %%
print('Ola Mundo')
# Out:
# Ola Mundo

# %%
print("Estou aprendendo python")
# Out:
# Estou aprendendo python

# %%
'Estou aprendendo python'
# Out:
# 'Estou aprendendo python'

# %%
1+1
# Out:
# 2

# %%
10-2
# Out:
# 8

# %%
#Esse é um comentário python

# %%
2*2 #Operacao produto
# Out:
# 4

# %%
10/2 #Operacao divisao
# Out:
# 5.0

# %%
a=4
b=6

# %%
a+
# Out:
#   File "<ipython-input-10-d589f663f6c7>", line 1
#     a+
#       ^
# SyntaxError: invalid syntax

# %%
a
# Out:
# 4

# %%
a+b
# Out:
# 10

# %%
frase = 'Python para analise de dados'

# %%
frase[0]
# Out:
# 'P'

# %%
frase[0:10]
# Out:
# 'Python par'

# %%
frase1=mesdenovembro
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-669b8f40485c> in <module>()
# ----> 1 frase1=mesdenovembro
#
# NameError: name 'mesdenovembro' is not defined

# %%
frase1 = 'mesdenovembro'

# %%
frase1[1:4]
# Out:
# 'esd'

# %%
frase [10:]
# Out:
# 'a analise de dados'

# %%
frase[:17]
# Out:
# 'Python para anali'

# %%
frase.count('Dados')
# Out:
# 0

# %%
frase.count('a')
# Out:
# 5

# %%
frase.lower()
# Out:
# 'python para analise de dados'

# %%
frase.upper()
# Out:
# 'PYTHON PARA ANALISE DE DADOS'

# %%
frase.replace('Python', 'R')
# Out:
# 'R para analise de dados'

# %%
frase()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-fddeb9735ec8> in <module>()
# ----> 1 frase()
#
# TypeError: 'str' object is not callable

# %%
frase
# Out:
# 'Python para analise de dados'

# %%
frase = frase.upper()

# %%
frase
# Out:
# 'PYTHON PARA ANALISE DE DADOS'
